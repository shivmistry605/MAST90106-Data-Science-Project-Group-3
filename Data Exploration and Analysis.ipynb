# %%
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %%
df = pd.read_csv (r'C:\Users\shiv mistry\Downloads\dta.csv')

# %%
df.head()
# Out:
#   SampleID/AnalyteID       IGSN  \
# 0              A1-1   IEMTG01OP
# 1             A1-10   IEMTG01OQ
# 2              A1-2   IEMTG01OR
# 3              A1-3   IEMTG01OS
# 4              A1-4   IEMTG01OT
#
#                                            IGSN URL  \
# 0  https://app.geosamples.org/sample/igsn/IEMTG01OP
# 1  https://app.geosamples.org/sample/igsn/IEMTG01OQ
# 2  https://app.geosamples.org/sample/igsn/IEMTG01OR
# 3  https://app.geosamples.org/sample/igsn/IEMTG01OS
# 4  https://app.geosamples.org/sample/igsn/IEMTG01OT
#
#                                    Reference_DOI   Reference_authors  \
# 0  https://doi.org/10.1016/S0040-1951(02)00057-4  House et al., 2002
# 1  https://doi.org/10.1016/S0040-1951(02)00057-4  House et al., 2002
# 2  https://doi.org/10.1016/S0040-1951(02)00057-4  House et al., 2002
# 3  https://doi.org/10.1016/S0040-1951(02)00057-4  House et al., 2002
# 4  https://doi.org/10.1016/S0040-1951(02)00057-4  House et al., 2002
#
#   Reference_journal Reference_year  \
# 0    Tectonophysics           2002
# 1    Tectonophysics           2002
# 2    Tectonophysics           2002
# 3    Tectonophysics           2002
# 4    Tectonophysics           2002
#
#                                      Reference_title lat; WGS84, decDegr  \
# 0  Evaluating thermal history models for the Otwa...             -38.407
# 1  Evaluating thermal history models for the Otwa...             -38.407
# 2  Evaluating thermal history models for the Otwa...             -38.407
# 3  Evaluating thermal history models for the Otwa...             -38.407
# 4  Evaluating thermal history models for the Otwa...             -38.407
#
#    long; WGS84, decDegr  ...  Date Collected (minimum) - Default  \
# 0               144.198  ...                                 NaN
# 1               144.198  ...                                 NaN
# 2               144.198  ...                                 NaN
# 3               144.198  ...                                 NaN
# 4               144.198  ...                                 NaN
#
#    Date Collected (maximum)  Person OrcID Last known sample archive location  \
# 0                       NaN  A Raza   NaN         Melbourne Thermochronology
# 1                       NaN  A Raza   NaN         Melbourne Thermochronology
# 2                       NaN  A Raza   NaN         Melbourne Thermochronology
# 3                       NaN  A Raza   NaN         Melbourne Thermochronology
# 4                       NaN  A Raza   NaN         Melbourne Thermochronology
#
#                Archive contact Archive comment Grant_ID Funding_body  \
# 0  samuel.boone@unimelb.edu.au             NaN      NaN          NaN
# 1  samuel.boone@unimelb.edu.au             NaN      NaN          NaN
# 2  samuel.boone@unimelb.edu.au             NaN      NaN          NaN
# 3  samuel.boone@unimelb.edu.au             NaN      NaN          NaN
# 4  samuel.boone@unimelb.edu.au             NaN      NaN          NaN
#
#   Fund_comment
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 37 columns]

# %%
df.tail()
# Out:
#      SampleID/AnalyteID       IGSN  \
# 3147                 W2  IEMTG02CU
# 3148                 W3  IEMTG02CV
# 3149                 W4  IEMTG02D3
# 3150                 W5  IEMTG02D5
# 3151                 W6  IEMTG02D6
#
#                                               IGSN URL Reference_DOI  \
# 3147  https://app.geosamples.org/sample/igsn/IEMTG02CU           NaN
# 3148  https://app.geosamples.org/sample/igsn/IEMTG02CV           NaN
# 3149  https://app.geosamples.org/sample/igsn/IEMTG02D3           NaN
# 3150  https://app.geosamples.org/sample/igsn/IEMTG02D5           NaN
# 3151  https://app.geosamples.org/sample/igsn/IEMTG02D6           NaN
#
#      Reference_authors Reference_journal Reference_year Reference_title  \
# 3147               NaN               NaN            NaN             NaN
# 3148               NaN               NaN            NaN             NaN
# 3149               NaN               NaN            NaN             NaN
# 3150               NaN               NaN            NaN             NaN
# 3151               NaN               NaN            NaN             NaN
#
#      lat; WGS84, decDegr  long; WGS84, decDegr  ...  \
# 3147             -30.311               133.527  ...
# 3148             -30.244               133.954  ...
# 3149             -30.933               135.528  ...
# 3150             -29.902               133.749  ...
# 3151             -30.228               134.083  ...
#
#       Date Collected (minimum) - Default  Date Collected (maximum)  Person  \
# 3147                                 NaN                       NaN     NaN
# 3148                                 NaN                       NaN     NaN
# 3149                                 NaN                       NaN     NaN
# 3150                                 NaN                       NaN     NaN
# 3151                                 NaN                       NaN     NaN
#
#      OrcID Last known sample archive location              Archive contact  \
# 3147   NaN         Melbourne Thermochronology  samuel.boone@unimelb.edu.au
# 3148   NaN         Melbourne Thermochronology  samuel.boone@unimelb.edu.au
# 3149   NaN         Melbourne Thermochronology  samuel.boone@unimelb.edu.au
# 3150   NaN         Melbourne Thermochronology  samuel.boone@unimelb.edu.au
# 3151   NaN         Melbourne Thermochronology  samuel.boone@unimelb.edu.au
#
#      Archive comment Grant_ID Funding_body Fund_comment
# 3147             NaN      NaN          NaN          NaN
# 3148             NaN      NaN          NaN          NaN
# 3149             NaN      NaN          NaN          NaN
# 3150             NaN      NaN          NaN          NaN
# 3151             NaN      NaN          NaN          NaN
#
# [5 rows x 37 columns]

# %%
df.dtypes
# Out:
# SampleID/AnalyteID                          object
# IGSN                                        object
# IGSN URL                                    object
# Reference_DOI                               object
# Reference_authors                           object
# Reference_journal                           object
# Reference_year                              object
# Reference_title                             object
# lat; WGS84, decDegr                         object
# long; WGS84, decDegr                       float64
# lat/long precision_m                       float64
# sample comment                             float64
# elevation_m                                float64
# vertical_datum_id                           object
# location_capture_type_id                    object
# location_kind_id                            object
# loc_name                                    object
# loc_comment                                 object
# sample_type                                 object
# lithology_id                                object
# mineral_id                                 float64
# Stratigraphic unit (name) GA_list           object
# unit_age (Eon, era, period, epoch, age)     object
# unit age_min - Default                     float64
# unit age_max                                object
# depth_min - Default                        float64
# depth_max                                  float64
# Date Collected (minimum) - Default         float64
# Date Collected (maximum)                   float64
# Person                                      object
# OrcID                                       object
# Last known sample archive location          object
# Archive contact                             object
# Archive comment                            float64
# Grant_ID                                    object
# Funding_body                                object
# Fund_comment                               float64
# dtype: object

# %%
print("Shape of Dataframe: ",df.shape)

#Finding duplicate rows
duplicate_rows_df = df[df.duplicated()]
print("Number of duplicate rows: ",duplicate_rows_df.shape)
# Out:
# (3152, 37)
# number of duplicate rows:  (0, 37)

# %%
# Finding the null values
print(df.isnull().sum())
# Out:
# SampleID/AnalyteID                            0
# IGSN                                        355
# IGSN URL                                    355
# Reference_DOI                              2014
# Reference_authors                           253
# Reference_journal                          1094
# Reference_year                              247
# Reference_title                            1148
# lat; WGS84, decDegr                          30
# long; WGS84, decDegr                         30
# lat/long precision_m                        137
# sample comment                             3152
# elevation_m                                1447
# vertical_datum_id                           822
# location_capture_type_id                      0
# location_kind_id                              0
# loc_name                                   3064
# loc_comment                                3086
# sample_type                                   0
# lithology_id                                121
# mineral_id                                 3152
# Stratigraphic unit (name) GA_list           495
# unit_age (Eon, era, period, epoch, age)     334
# unit age_min - Default                      270
# unit age_max                                261
# depth_min - Default                        2156
# depth_max                                  2868
# Date Collected (minimum) - Default         3152
# Date Collected (maximum)                   3152
# Person                                      434
# OrcID                                      1523
# Last known sample archive location           82
# Archive contact                              82
# Archive comment                            3152
# Grant_ID                                   3126
# Funding_body                               3126
# Fund_comment                               3152
# dtype: int64
